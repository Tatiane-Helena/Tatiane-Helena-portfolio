# %% [markdown]
# ### Retail Coffee shop
#
# We have collected a dataset which contains sales of one week in a coffee retail shop. The week sales has been described by hour.
#
# In order to do the analysis of this dataset, it will be used the Time-Series method and let's see what we are the insights we can possibly find out in this data.
#
# The problem: To determine the exaclty number of staff for a day shift, focusing on reducing cost which means keep the labour-cost below 31% and keep high performance in store in order to deliver a great quality service for customers.

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from datetime import datetime


import warnings
warnings.filterwarnings('ignore') # We can suppress the warnings

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(10, 4)})
plt.rcParams['figure.figsize'] = (6,4)
plt.rcParams['figure.dpi'] = 150

# %%
data = pd.read_excel('hourly sale week ending 6th.xlsx')

# %%
data.head()
# Out:
#                        Unnamed: 0  0615  0630      0645       0700       0715  \
# 0  OC158 Abbey Street, 30/09/2024   NaN   NaN       NaN   7.929516  47.048459
# 1  OC158 Abbey Street, 01/10/2024   NaN   NaN       NaN  23.215860  19.162996
# 2  OC158 Abbey Street, 02/10/2024   NaN   NaN  4.273128  18.898680  31.530926
# 3  OC158 Abbey Street, 03/10/2024   NaN   NaN       NaN  44.411197  26.651983
# 4  OC158 Abbey Street, 04/10/2024   NaN   NaN       NaN  30.044055  17.491851
#
#         0730       0745       0800       0815  ...          1800  1815  1830  \
# 0   3.920705  40.088106  30.070378  64.190933  ...  0.000000e+00   NaN   NaN
# 1  17.136564  47.533040  42.466961  48.013178  ...           NaN   NaN   NaN
# 2  21.277533  38.193832  50.572688  53.524230  ... -3.330669e-16   NaN   NaN
# 3  29.162998  34.449339  33.744493  78.945599  ...  0.000000e+00   NaN   NaN
# 4  18.402202  34.933921  53.392071  36.828195  ...  0.000000e+00   NaN   NaN
#
#    1845  1900  1915  1930  1945  2000  Grand Total
# 0   NaN   NaN   NaN   NaN   NaN   NaN  1536.837345
# 1   NaN   NaN   NaN   NaN   NaN   NaN  1363.574609
# 2   NaN   NaN   NaN   NaN   NaN   NaN  1590.105937
# 3   NaN   NaN   NaN   NaN   NaN   NaN  1445.205866
# 4   NaN   NaN   NaN   NaN   NaN   NaN  1321.526463
#
# [5 rows x 58 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 58 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   117 non-null    object
#  1   0615         10 non-null     float64
#  2   0630         12 non-null     float64
#  3   0645         15 non-null     float64
#  4   0700         36 non-null     float64
#  5   0715         36 non-null     float64
#  6   0730         65 non-null     float64
#  7   0745         73 non-null     float64
#  8   0800         98 non-null     float64
#  9   0815         98 non-null     float64
#  10  0830         106 non-null    float64
#  11  0845         109 non-null    float64
#  12  0900         112 non-null    float64
#  13  0915         114 non-null    float64
#  14  0930         116 non-null    float64
#  15  0945         116 non-null    float64
#  16  1000         117 non-null    float64
#  17  1015         117 non-null    float64
#  18  1030         116 non-null    float64
#  19  1045         117 non-null    float64
#  20  1100         116 non-null    float64
#  21  1115         117 non-null    float64
#  22  1130         117 non-null    float64
#  23  1145         117 non-null    float64
#  24  1200         114 non-null    float64
#  25  1215         116 non-null    float64
#  26  1230         117 non-null    float64
#  27  1245         117 non-null    float64
#  28  1300         117 non-null    float64
#  29  1315         116 non-null    float64
#  30  1330         116 non-null    float64
#  31  1345         116 non-null    float64
#  32  1400         115 non-null    float64
#  33  1415         115 non-null    float64
#  34  1430         114 non-null    float64
#  35  1445         114 non-null    float64
#  36  1500         115 non-null    float64
#  37  1515         112 non-null    float64
#  38  1530         113 non-null    float64
#  39  1545         102 non-null    float64
#  40  1600         103 non-null    float64
#  41  1615         106 non-null    float64
#  42  1630         99 non-null     float64
#  43  1645         99 non-null     float64
#  44  1700         85 non-null     float64
#  45  1715         69 non-null     float64
#  46  1730         53 non-null     float64
#  47  1745         41 non-null     float64
#  48  1800         29 non-null     float64
#  49  1815         16 non-null     float64
#  50  1830         13 non-null     float64
#  51  1845         11 non-null     float64
#  52  1900         8 non-null      float64
#  53  1915         8 non-null      float64
#  54  1930         8 non-null      float64
#  55  1945         7 non-null      float64
#  56  2000         7 non-null      float64
#  57  Grand Total  117 non-null    float64
# dtypes: float64(57), object(1)
# memory usage: 53.1+ KB

# %%
df_melted = pd.melt(data, id_vars=['Unnamed: 0'], var_name='Time', value_name='Sales')

print(df_melted)
# Out:
#                               Unnamed: 0         Time          Sales
# 0         OC158 Abbey Street, 30/09/2024         0615            NaN
# 1         OC158 Abbey Street, 01/10/2024         0615            NaN
# 2         OC158 Abbey Street, 02/10/2024         0615            NaN
# 3         OC158 Abbey Street, 03/10/2024         0615            NaN
# 4         OC158 Abbey Street, 04/10/2024         0615            NaN
# ...                                  ...          ...            ...
# 6664  OC254 Connolly Station, 03/10/2024  Grand Total    1893.085933
# 6665  OC254 Connolly Station, 04/10/2024  Grand Total    1949.016947
# 6666  OC254 Connolly Station, 05/10/2024  Grand Total    1567.726733
# 6667  OC254 Connolly Station, 06/10/2024  Grand Total    1215.311291
# 6668                         Grand Total  Grand Total  157224.718009
#
# [6669 rows x 3 columns]

# %%
df_melted.head(10)
# Out:
#                        Unnamed: 0  Time  Sales
# 0  OC158 Abbey Street, 30/09/2024  0615    NaN
# 1  OC158 Abbey Street, 01/10/2024  0615    NaN
# 2  OC158 Abbey Street, 02/10/2024  0615    NaN
# 3  OC158 Abbey Street, 03/10/2024  0615    NaN
# 4  OC158 Abbey Street, 04/10/2024  0615    NaN
# 5  OC158 Abbey Street, 05/10/2024  0615    NaN
# 6  OC158 Abbey Street, 06/10/2024  0615    NaN
# 7       OC175 Leixlip, 30/09/2024  0615    NaN
# 8       OC175 Leixlip, 01/10/2024  0615    NaN
# 9       OC175 Leixlip, 02/10/2024  0615    NaN

# %%
df_melted['Unnamed: 0'].unique()
# Out:
# array(['OC158 Abbey Street, 30/09/2024', 'OC158 Abbey Street, 01/10/2024',
#        'OC158 Abbey Street, 02/10/2024', 'OC158 Abbey Street, 03/10/2024',
#        'OC158 Abbey Street, 04/10/2024', 'OC158 Abbey Street, 05/10/2024',
#        'OC158 Abbey Street, 06/10/2024', 'OC175 Leixlip, 30/09/2024',
#        'OC175 Leixlip, 01/10/2024', 'OC175 Leixlip, 02/10/2024',
#        'OC175 Leixlip, 03/10/2024', 'OC175 Leixlip, 04/10/2024',
#        'OC175 Leixlip, 05/10/2024', 'OC175 Leixlip, 06/10/2024',
#        'OC186 Carpenterstown, 30/09/2024',
#        'OC186 Carpenterstown, 01/10/2024',
#        'OC186 Carpenterstown, 02/10/2024',
#        'OC186 Carpenterstown, 03/10/2024',
#        'OC186 Carpenterstown, 04/10/2024',
#        'OC186 Carpenterstown, 05/10/2024',
#        'OC186 Carpenterstown, 06/10/2024', 'OC190 Ashbourne, 30/09/2024',
#        'OC190 Ashbourne, 01/10/2024', 'OC190 Ashbourne, 02/10/2024',
#        'OC190 Ashbourne, 03/10/2024', 'OC190 Ashbourne, 04/10/2024',
#        'OC190 Ashbourne, 05/10/2024', 'OC190 Ashbourne, 06/10/2024',
#        'OC195 Glen Easton, 30/09/2024', 'OC195 Glen Easton, 01/10/2024',
#        'OC195 Glen Easton, 02/10/2024', 'OC195 Glen Easton, 03/10/2024',
#        'OC195 Glen Easton, 04/10/2024', 'OC195 Glen Easton, 05/10/2024',
#        'OC195 Glen Easton, 06/10/2024', 'OC197 Navan Road, 30/09/2024',
#        'OC197 Navan Road, 01/10/2024', 'OC197 Navan Road, 02/10/2024',
#        'OC197 Navan Road, 03/10/2024', 'OC197 Navan Road, 04/10/2024',
#        'OC197 Navan Road, 05/10/2024', 'OC197 Navan Road, 06/10/2024',
#        'OC198 HSQ, 30/09/2024', 'OC198 HSQ, 01/10/2024',
#        'OC198 HSQ, 02/10/2024', 'OC198 HSQ, 03/10/2024',
#        'OC198 HSQ, 04/10/2024', 'OC198 HSQ, 05/10/2024',
#        'OC198 HSQ, 06/10/2024', 'OC206 Blanchardstown, 30/09/2024',
#        'OC206 Blanchardstown, 01/10/2024',
#        'OC206 Blanchardstown, 02/10/2024',
#        'OC206 Blanchardstown, 03/10/2024',
#        'OC206 Blanchardstown, 04/10/2024',
#        'OC206 Blanchardstown, 05/10/2024',
#        'OC206 Blanchardstown, 06/10/2024', 'OC217 Drumcondra, 30/09/2024',
#        'OC217 Drumcondra, 01/10/2024', 'OC217 Drumcondra, 02/10/2024',
#        'OC217 Drumcondra, 03/10/2024', 'OC217 Drumcondra, 04/10/2024',
#        'OC217 Drumcondra, 05/10/2024', 'OC217 Drumcondra, 06/10/2024',
#        'OC221 Macken House, 30/09/2024', 'OC221 Macken House, 01/10/2024',
#        'OC221 Macken House, 02/10/2024', 'OC221 Macken House, 03/10/2024',
#        'OC221 Macken House, 04/10/2024', 'OC221 Macken House, 05/10/2024',
#        'OC222 Parkwest, 30/09/2024', 'OC222 Parkwest, 01/10/2024',
#        'OC222 Parkwest, 02/10/2024', 'OC222 Parkwest, 03/10/2024',
#        'OC222 Parkwest, 04/10/2024', 'OC232 Gardiner Street, 30/09/2024',
#        'OC232 Gardiner Street, 01/10/2024',
#        'OC232 Gardiner Street, 02/10/2024',
#        'OC232 Gardiner Street, 03/10/2024',
#        'OC232 Gardiner Street, 04/10/2024',
#        'OC232 Gardiner Street, 05/10/2024',
#        'OC232 Gardiner Street, 06/10/2024', 'OC239 Naas, 30/09/2024',
#        'OC239 Naas, 01/10/2024', 'OC239 Naas, 02/10/2024',
#        'OC239 Naas, 03/10/2024', 'OC239 Naas, 04/10/2024',
#        'OC239 Naas, 05/10/2024', 'OC239 Naas, 06/10/2024',
#        'OC245 Palmerstown, 30/09/2024', 'OC245 Palmerstown, 01/10/2024',
#        'OC245 Palmerstown, 02/10/2024', 'OC245 Palmerstown, 03/10/2024',
#        'OC245 Palmerstown, 04/10/2024', 'OC245 Palmerstown, 05/10/2024',
#        'OC245 Palmerstown, 06/10/2024', 'OC246 Dorset St, 30/09/2024',
#        'OC246 Dorset St, 01/10/2024', 'OC246 Dorset St, 02/10/2024',
#        'OC246 Dorset St, 03/10/2024', 'OC246 Dorset St, 04/10/2024',
#        'OC246 Dorset St, 05/10/2024', 'OC246 Dorset St, 06/10/2024',
#        'OC249 Adamstown, 30/09/2024', 'OC249 Adamstown, 01/10/2024',
#        'OC249 Adamstown, 02/10/2024', 'OC249 Adamstown, 03/10/2024',
#        'OC249 Adamstown, 04/10/2024', 'OC249 Adamstown, 05/10/2024',
#        'OC249 Adamstown, 06/10/2024',
#        'OC254 Connolly Station, 30/09/2024',
#        'OC254 Connolly Station, 01/10/2024',
#        'OC254 Connolly Station, 02/10/2024',
#        'OC254 Connolly Station, 03/10/2024',
#        'OC254 Connolly Station, 04/10/2024',
#        'OC254 Connolly Station, 05/10/2024',
#        'OC254 Connolly Station, 06/10/2024', 'Grand Total'], dtype=object)

# %%
df_melted.rename(columns = ({'Unnamed: 0': 'Stores'}), inplace=True)

print(df_melted)
# Out:
#                                   Stores         Time          Sales
# 0         OC158 Abbey Street, 30/09/2024         0615            NaN
# 1         OC158 Abbey Street, 01/10/2024         0615            NaN
# 2         OC158 Abbey Street, 02/10/2024         0615            NaN
# 3         OC158 Abbey Street, 03/10/2024         0615            NaN
# 4         OC158 Abbey Street, 04/10/2024         0615            NaN
# ...                                  ...          ...            ...
# 6664  OC254 Connolly Station, 03/10/2024  Grand Total    1893.085933
# 6665  OC254 Connolly Station, 04/10/2024  Grand Total    1949.016947
# 6666  OC254 Connolly Station, 05/10/2024  Grand Total    1567.726733
# 6667  OC254 Connolly Station, 06/10/2024  Grand Total    1215.311291
# 6668                         Grand Total  Grand Total  157224.718009
#
# [6669 rows x 3 columns]

# %%
df_melted.columns = df_melted.columns.str.strip()  # Remove leading/trailing spaces
df_melted.columns = df_melted.columns.astype(str)  # Ensure all columns are strings

# %%
store_name = 'OC217 Drumcondra'
df_store= df_melted[df_melted['Stores'].str.contains(store_name, na=False)]

print(df_store)
# Out:
#                             Stores         Time        Sales
# 56    OC217 Drumcondra, 30/09/2024         0615          NaN
# 57    OC217 Drumcondra, 01/10/2024         0615          NaN
# 58    OC217 Drumcondra, 02/10/2024         0615          NaN
# 59    OC217 Drumcondra, 03/10/2024         0615          NaN
# 60    OC217 Drumcondra, 04/10/2024         0615          NaN
# ...                            ...          ...          ...
# 6610  OC217 Drumcondra, 02/10/2024  Grand Total  2082.042054
# 6611  OC217 Drumcondra, 03/10/2024  Grand Total  2067.444000
# 6612  OC217 Drumcondra, 04/10/2024  Grand Total  2299.894353
# 6613  OC217 Drumcondra, 05/10/2024  Grand Total  2397.571909
# 6614  OC217 Drumcondra, 06/10/2024  Grand Total  2046.513854
#
# [399 rows x 3 columns]

# %%
# Extract the date from 'Stores' column
df_store['Date'] = df_store['Stores'].str.extract(r'(\d{2}/\d{2}/\d{4})')
df_store['Date'] = pd.to_datetime(df_store['Date'], format='%d/%m/%Y')

print(df_store)
# Out:
#                             Stores         Time        Sales       Date
# 56    OC217 Drumcondra, 30/09/2024         0615          NaN 2024-09-30
# 57    OC217 Drumcondra, 01/10/2024         0615          NaN 2024-10-01
# 58    OC217 Drumcondra, 02/10/2024         0615          NaN 2024-10-02
# 59    OC217 Drumcondra, 03/10/2024         0615          NaN 2024-10-03
# 60    OC217 Drumcondra, 04/10/2024         0615          NaN 2024-10-04
# ...                            ...          ...          ...        ...
# 6610  OC217 Drumcondra, 02/10/2024  Grand Total  2082.042054 2024-10-02
# 6611  OC217 Drumcondra, 03/10/2024  Grand Total  2067.444000 2024-10-03
# 6612  OC217 Drumcondra, 04/10/2024  Grand Total  2299.894353 2024-10-04
# 6613  OC217 Drumcondra, 05/10/2024  Grand Total  2397.571909 2024-10-05
# 6614  OC217 Drumcondra, 06/10/2024  Grand Total  2046.513854 2024-10-06
#
# [399 rows x 4 columns]

# %%
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399 entries, 56 to 6614
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Stores  399 non-null    object
#  1   Time    399 non-null    object
#  2   Sales   315 non-null    float64
#  3   Date    399 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 15.6+ KB

# %%
print(df_store.columns)
# Out:
# Index(['Stores', 'Time', 'Sales', 'Date'], dtype='object')

# %%
df_store.head()
# Out:
#                           Stores  Time  Sales       Date
# 56  OC217 Drumcondra, 30/09/2024  0615    NaN 2024-09-30
# 57  OC217 Drumcondra, 01/10/2024  0615    NaN 2024-10-01
# 58  OC217 Drumcondra, 02/10/2024  0615    NaN 2024-10-02
# 59  OC217 Drumcondra, 03/10/2024  0615    NaN 2024-10-03
# 60  OC217 Drumcondra, 04/10/2024  0615    NaN 2024-10-04

# %%
df_store.tail(10)
# Out:
#                             Stores         Time        Sales       Date
# 6495  OC217 Drumcondra, 04/10/2024         2000          NaN 2024-10-04
# 6496  OC217 Drumcondra, 05/10/2024         2000          NaN 2024-10-05
# 6497  OC217 Drumcondra, 06/10/2024         2000          NaN 2024-10-06
# 6608  OC217 Drumcondra, 30/09/2024  Grand Total  2042.757577 2024-09-30
# 6609  OC217 Drumcondra, 01/10/2024  Grand Total  1931.940308 2024-10-01
# 6610  OC217 Drumcondra, 02/10/2024  Grand Total  2082.042054 2024-10-02
# 6611  OC217 Drumcondra, 03/10/2024  Grand Total  2067.444000 2024-10-03
# 6612  OC217 Drumcondra, 04/10/2024  Grand Total  2299.894353 2024-10-04
# 6613  OC217 Drumcondra, 05/10/2024  Grand Total  2397.571909 2024-10-05
# 6614  OC217 Drumcondra, 06/10/2024  Grand Total  2046.513854 2024-10-06

# %% [markdown]
# ### Dropping rows with the sales grand total that will not be used in the analysis

# %%
indices_to_drop = [6608, 6609,6610, 6611, 6612, 6613, 6614]

df_store = df_store.drop(indices_to_drop)

# %%
df_store
# Out:
#                             Stores  Time  Sales       Date
# 56    OC217 Drumcondra, 30/09/2024  0615    NaN 2024-09-30
# 57    OC217 Drumcondra, 01/10/2024  0615    NaN 2024-10-01
# 58    OC217 Drumcondra, 02/10/2024  0615    NaN 2024-10-02
# 59    OC217 Drumcondra, 03/10/2024  0615    NaN 2024-10-03
# 60    OC217 Drumcondra, 04/10/2024  0615    NaN 2024-10-04
# ...                            ...   ...    ...        ...
# 6493  OC217 Drumcondra, 02/10/2024  2000    NaN 2024-10-02
# 6494  OC217 Drumcondra, 03/10/2024  2000    NaN 2024-10-03
# 6495  OC217 Drumcondra, 04/10/2024  2000    NaN 2024-10-04
# 6496  OC217 Drumcondra, 05/10/2024  2000    NaN 2024-10-05
# 6497  OC217 Drumcondra, 06/10/2024  2000    NaN 2024-10-06
#
# [392 rows x 4 columns]

# %%
# Convert Time column to string if needed
df_store['Time'] = df_store['Time'].astype(str)

# Combine Date and Time
df_store['Datetime'] = pd.to_datetime(df_store['Date'].astype(str) + ' ' + df_store['Time'])

# Set datetime as index
df_store = df_store.set_index('Datetime')

# Sort index (important for time series)
df_store = df_store.sort_index()

print(df_store.head())
# Out:
#                                            Stores  Time  Sales       Date
# Datetime
# 2024-09-30 06:15:00  OC217 Drumcondra, 30/09/2024  0615    NaN 2024-09-30
# 2024-09-30 06:30:00  OC217 Drumcondra, 30/09/2024  0630    NaN 2024-09-30
# 2024-09-30 06:45:00  OC217 Drumcondra, 30/09/2024  0645    NaN 2024-09-30
# 2024-09-30 07:00:00  OC217 Drumcondra, 30/09/2024  0700    NaN 2024-09-30
# 2024-09-30 07:15:00  OC217 Drumcondra, 30/09/2024  0715    NaN 2024-09-30

# %%
new = df_store[['Time', 'Sales', 'Date']]

new.head()
# Out:
#                      Time  Sales       Date
# Datetime
# 2024-09-30 06:15:00  0615    NaN 2024-09-30
# 2024-09-30 06:30:00  0630    NaN 2024-09-30
# 2024-09-30 06:45:00  0645    NaN 2024-09-30
# 2024-09-30 07:00:00  0700    NaN 2024-09-30
# 2024-09-30 07:15:00  0715    NaN 2024-09-30

# %%
new.dtypes
# Out:
# Time             object
# Sales           float64
# Date     datetime64[ns]
# dtype: object

# %%
dfnew = new[['Sales']]

dfnew.head()
# Out:
#                      Sales
# Datetime
# 2024-09-30 06:15:00    NaN
# 2024-09-30 06:30:00    NaN
# 2024-09-30 06:45:00    NaN
# 2024-09-30 07:00:00    NaN
# 2024-09-30 07:15:00    NaN

# %% [markdown]
# ### Verifying 'Datetime' feature has set up as DatetimeIndex.

# %%
dfnew.index
# Out:
# DatetimeIndex(['2024-09-30 06:15:00', '2024-09-30 06:30:00',
#                '2024-09-30 06:45:00', '2024-09-30 07:00:00',
#                '2024-09-30 07:15:00', '2024-09-30 07:30:00',
#                '2024-09-30 07:45:00', '2024-09-30 08:00:00',
#                '2024-09-30 08:15:00', '2024-09-30 08:30:00',
#                ...
#                '2024-10-06 17:45:00', '2024-10-06 18:00:00',
#                '2024-10-06 18:15:00', '2024-10-06 18:30:00',
#                '2024-10-06 18:45:00', '2024-10-06 19:00:00',
#                '2024-10-06 19:15:00', '2024-10-06 19:30:00',
#                '2024-10-06 19:45:00', '2024-10-06 20:00:00'],
#               dtype='datetime64[ns]', name='Datetime', length=392, freq=None)

# %%
business_hour = dfnew[(dfnew.index.time >= pd.to_datetime("07:30").time()) & 
        (dfnew.index.time <= pd.to_datetime("18:30").time())]

business_hour
# Out:
#                          Sales
# Datetime
# 2024-09-30 07:30:00  31.321587
# 2024-09-30 07:45:00  34.933921
# 2024-09-30 08:00:00  12.643172
# 2024-09-30 08:15:00  46.960354
# 2024-09-30 08:30:00  28.267614
# ...                        ...
# 2024-10-06 17:30:00  36.519824
# 2024-10-06 17:45:00  10.396476
# 2024-10-06 18:00:00   8.370044
# 2024-10-06 18:15:00  36.809497
# 2024-10-06 18:30:00   0.000000
#
# [315 rows x 1 columns]

# %%
drop_na_strategy = df_store[['Sales']].dropna()

# %%
drop_na_strategy.head()
# Out:
#                          Sales
# Datetime
# 2024-09-30 07:30:00  31.321587
# 2024-09-30 07:45:00  34.933921
# 2024-09-30 08:00:00  12.643172
# 2024-09-30 08:15:00  46.960354
# 2024-09-30 08:30:00  28.267614

# %%
drop_na_strategy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 308 entries, 2024-09-30 07:30:00 to 2024-10-06 18:30:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   308 non-null    float64
# dtypes: float64(1)
# memory usage: 4.8 KB

# %% [markdown]
# ### Plot Timeseries

# %%
ax = drop_na_strategy['Sales'].plot(linestyle='-')

ax.set_xlabel("Datetime (Hours)")
ax.set_ylabel("Sales")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
#Visualizing by hour 
sales_hourly = drop_na_strategy.groupby(drop_na_strategy.index.hour)['Sales'].sum()

sales_hourly.plot(marker='o')
plt.xlabel("Hour of Day")
plt.ylabel("Total Sales")
plt.title("Sales by Hour")
plt.show()

# %% [markdown]
# ### Sales 30th September 24 from 7:30 am to 18:30 pm

# %%
ax = drop_na_strategy.loc['2024-09-30 07:30:00':'2024-09-30 13:00:00',
'Sales'].plot(marker='o', linestyle='-')
ax.set_ylabel('Sales');

# %% [markdown]
# ### Sales from 11:30 am to 15:00 pm

# %%
ax = drop_na_strategy.loc['2024-10-01 13:00:00':'2024-10-01 18:30:00',
'Sales'].plot(marker='o', linestyle='-')
ax.set_ylabel('Sales()');

# %%
newdata = drop_na_strategy[['Sales']]

newdata.index = pd.to_datetime(newdata.index)

newdata = newdata.asfreq('H')   # hourly data

# %%
newdata.plot(figsize=(10,5), title="Hourly Coffee Shop Sales")
plt.show()

# %%
missing = newdata[newdata['Sales'].isna()]
print(missing.head())
print("Total missing values:", missing.shape[0])
# Out:
#                      Sales
# Datetime
# 2024-09-30 19:30:00    NaN
# 2024-09-30 20:30:00    NaN
# 2024-09-30 21:30:00    NaN
# 2024-09-30 22:30:00    NaN
# 2024-09-30 23:30:00    NaN
# Total missing values: 76

# %%
plt.figure(figsize=(12,5))

plt.plot(newdata['Sales'], label="Sales")

# highlight missing values
plt.scatter(
    newdata.index[newdata['Sales'].isna()],
    [0]*newdata['Sales'].isna().sum(),
    color='red',
    label='Missing'
)

plt.legend()
plt.title("Missing Values in Time Series")
plt.show()

# %% [markdown]
# ## Filling in Missing Data
#
# In this case the fillna method was used to replaces the missing values with 0 because in the plot above it can see that these missing values are from the time the shop is closed.

# %%
newdata = newdata.fillna(0)

# %%
print(newdata.isna().sum())
# Out:
# Sales    0
# dtype: int64

# %% [markdown]
# ## Checking if the time serie is stationary

# %%
## Augmented Dickey–Fuller Test checks whether a time series is stationary.
from statsmodels.tsa.stattools import adfuller

result = adfuller(newdata['Sales'])

print("ADF Statistic:", result[0])
print("p-value:", result[1])

for key, value in result[4].items():
    print('Critical Value (%s): %.3f' % (key, value))
# Out:
# ADF Statistic: -6.4108582388128745
# p-value: 1.8924266036059784e-08
# Critical Value (1%): -3.477
# Critical Value (5%): -2.882
# Critical Value (10%): -2.578

# %% [markdown]
# ## p-value < 0.05 that means serie is stationary.
#
# #### p-value > 0.05 that means serie is not stationary.

# %%
# !pip install pmdarima
from pmdarima.arima import auto_arima
# Out:
# Requirement already satisfied: pmdarima in c:\users\lenovo\anaconda3\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\lenovo\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\lenovo\anaconda3\lib\site-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\lenovo\anaconda3\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\lenovo\anaconda3\lib\site-packages (from pmdarima) (1.5.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in c:\users\lenovo\anaconda3\lib\site-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pmdarima) (75.1.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lenovo\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in c:\users\lenovo\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
train = newdata.iloc[:-16]
test = newdata.iloc[-16:]

train, test.shape
# Out:
# (                         Sales
#  Datetime
#  2024-09-30 07:30:00  31.321587
#  2024-09-30 08:30:00  28.267614
#  2024-09-30 09:30:00  35.991191
#  2024-09-30 10:30:00  51.841803
#  2024-09-30 11:30:00  23.269404
#  ...                        ...
#  2024-10-05 22:30:00   0.000000
#  2024-10-05 23:30:00   0.000000
#  2024-10-06 00:30:00   0.000000
#  2024-10-06 01:30:00   0.000000
#  2024-10-06 02:30:00   0.000000
#
#  [140 rows x 1 columns],
#  (16, 1))

# %%
stepwise_model = auto_arima(
    train,
    start_p=0,
    start_q=0,
    max_p=5,
    max_q=5,
    seasonal=True,
    m=24, #seasonal: 24 hours 
    trace=True,
    stepwise=True,
    suppress_warnings=True
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(1,0,1)[24] intercept   : AIC=1262.369, Time=0.83 sec
#  ARIMA(0,0,0)(0,0,0)[24] intercept   : AIC=1356.933, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[24] intercept   : AIC=1260.747, Time=0.35 sec
#  ARIMA(0,0,1)(0,0,1)[24] intercept   : AIC=1280.951, Time=0.45 sec
#  ARIMA(0,0,0)(0,0,0)[24]             : AIC=1420.867, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[24] intercept   : AIC=1275.808, Time=0.22 sec
#  ARIMA(1,0,0)(2,0,0)[24] intercept   : AIC=1259.413, Time=1.90 sec
#  ARIMA(1,0,0)(2,0,1)[24] intercept   : AIC=inf, Time=4.06 sec
#  ARIMA(1,0,0)(1,0,1)[24] intercept   : AIC=inf, Time=1.06 sec
#  ARIMA(0,0,0)(2,0,0)[24] intercept   : AIC=inf, Time=1.82 sec
#  ARIMA(2,0,0)(2,0,0)[24] intercept   : AIC=1257.461, Time=2.79 sec
#  ARIMA(2,0,0)(1,0,0)[24] intercept   : AIC=1257.193, Time=0.77 sec
#  ARIMA(2,0,0)(0,0,0)[24] intercept   : AIC=1274.305, Time=0.12 sec
#  ARIMA(2,0,0)(1,0,1)[24] intercept   : AIC=inf, Time=1.35 sec
#  ARIMA(2,0,0)(0,0,1)[24] intercept   : AIC=1260.706, Time=0.43 sec
#  ARIMA(2,0,0)(2,0,1)[24] intercept   : AIC=inf, Time=5.87 sec
#  ARIMA(3,0,0)(1,0,0)[24] intercept   : AIC=1258.571, Time=0.70 sec
#  ARIMA(2,0,1)(1,0,0)[24] intercept   : AIC=1258.709, Time=0.89 sec
#  ARIMA(1,0,1)(1,0,0)[24] intercept   : AIC=1257.228, Time=0.74 sec
#  ARIMA(3,0,1)(1,0,0)[24] intercept   : AIC=1260.561, Time=1.33 sec
#  ARIMA(2,0,0)(1,0,0)[24]             : AIC=1263.845, Time=0.29 sec
#
# Best model:  ARIMA(2,0,0)(1,0,0)[24] intercept
# Total fit time: 26.062 seconds

# %%
forecast = stepwise_model.predict(n_periods=len(test))

forecast = pd.DataFrame(
    forecast,
    index=test.index,
    columns=["Forecast"]
)

# %%
forecast
# Out:
#                       Forecast
# Datetime
# 2024-10-06 03:30:00   5.490943
# 2024-10-06 04:30:00   7.422475
# 2024-10-06 05:30:00   9.184852
# 2024-10-06 06:30:00  10.185736
# 2024-10-06 07:30:00  10.885391
# 2024-10-06 08:30:00  26.492375
# 2024-10-06 09:30:00  62.214739
# 2024-10-06 10:30:00  52.241122
# 2024-10-06 11:30:00  36.395922
# 2024-10-06 12:30:00  51.765000
# 2024-10-06 13:30:00  48.461084
# 2024-10-06 14:30:00  22.766841
# 2024-10-06 15:30:00  27.327138
# 2024-10-06 16:30:00  24.728616
# 2024-10-06 17:30:00  38.783878
# 2024-10-06 18:30:00  12.162699

# %%
plt.figure(figsize=(10,5))

plt.plot(train, label="Training Data")
plt.plot(test, label="Actual Sales")
plt.plot(forecast, label="Forecast")

plt.legend()
plt.title("ARIMA Forecast vs Actual Sales")
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(newdata, label="Historical Sales")
plt.plot(forecast, label="Forecast", linewidth=3)

plt.legend()
plt.title("Coffee Shop Sales Forecast")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(test, forecast)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 17.924091644303648
